# %% [markdown]
# # BA1C Find the Reverse Complement of a String

# %%
def BA1C(s):
    rc = {'A' : 'T', 'G' : 'C',
         'C' : 'G', 'T' : 'A'}
    comp = ''.join([rc[x] for x in s])
    comp = comp[::-1]
    return(comp)

# %% [markdown]
# # Test

# %%
BA1C('AAAACCCGGT')
# Out:
# 'ACCGGGTTTT'

# %% [markdown]
# # Quiz

# %%
BA1C('...')
# Out:
# '...'
